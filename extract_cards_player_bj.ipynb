# %%
# %matplotlib widget

import os
import numpy as np
from PIL import Image
import cv2
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import patheffects as pe
import pytesseract
import matplotlib.patches as mpatches
from matplotlib.patches import Rectangle, Polygon
import image_utils
from get_cards_playing import card_peek_width, card_width, get_cards, card_height

# %%
img_path = "frames/player_blackjack.png"
img_np = image_utils.load_rdb(img_path)

print(f"Loaded {img_path}")
print(f"shape: {img_np.shape}, dtype: {img_np.dtype}")
# Out:
# Loaded frames/player_blackjack.png
# shape: (1080, 2280, 3), dtype: uint8

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 4))
ax.imshow(img_np)
ax.set_axis_off()

poly_pts = np.array([
    [1244, 484],
    [1249, 568],
    [1391, 568],
    [1382, 483],
], dtype=np.float32)

poly = Polygon(
    poly_pts, closed=True, fill=False, ec="black", lw=2
)
ax.add_patch(poly)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
cards = image_utils.wrap_perspective(img_np, poly_pts, card_width + card_peek_width, card_height)

f, ax = plt.subplots(1, 1, figsize=(8, 4))
ax.imshow(cards)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
get_cards(cards)
# Out:
# ['Qs', 'As']

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 7))
ax.imshow(digit_images[0][0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
