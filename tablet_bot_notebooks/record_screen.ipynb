# %%
# %matplotlib widget
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
from android_bot.image_utils import load_rdb, save_rgb_png
from android_bot.android_capture import ScreenCapture
import time
from android_bot import image_utils
import matplotlib.pyplot as plt
from android_bot.android_capture import ScreenCapture
import time
import matplotlib.pyplot as plt

# %%
scr_taker = None

# %%
del scr_taker

scr_taker = ScreenCapture(save_folder="/media/maxim/T7/frames/")
while True:
    scr_taker.get_screen()
    time.sleep(0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       4 while True:
#       5     scr_taker.get_screen()
# ----> 6     time.sleep(0.5)
#
# KeyboardInterrupt:

# %%
# capturer.close()

# %%
with ScreenCapture() as capturer:
    img_np = capturer.get_screen()

        
img_path = "frames_tablet/frame.png"
# img_np = image_utils.load_rdb(img_path)
image_utils.save_rgb_png(img_np, img_path)
img_np = image_utils.load_rdb(img_path)
