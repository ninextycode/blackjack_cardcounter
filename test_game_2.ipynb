# %%
# %matplotlib widget

import os
import numpy as np
from PIL import Image
import cv2
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import patheffects as pe
import pytesseract
import matplotlib.patches as mpatches
from matplotlib.patches import Rectangle, Polygon
import image_utils
from get_cards_tablet import card_peek_width, card_width, get_cards, card_height
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
from image_utils import load_rdb, save_rgb_png
from android_capture import ScreenCapture
import time
import image_utils
import ocr_cards
import matplotlib.pyplot as plt
from android_capture import ScreenCapture
import time
import image_utils
import get_cards_tablet
import ocr_cards
import matplotlib.pyplot as plt
from android_actions import AndroidBJTabletActor
from blackjack.actions import PlayerAction
from blackjack.cards import Card, Rank
from blackjack.hand import ValueOnlyHand
from blackjack.blackjack_round import BJRound, BJStage
from blackjack.rules import BJRules
from strategy import CardCounter, BasicStrategy, DeviatedBasicStrategy
from blackjack.actions import PlayerAction, DealerAction
import pandas as pd
from blackjack.cards import Rank
from datetime import datetime

# %%
rules = BJRules(
    dealer_checks_blackjack = True,
    dealer_hits_soft_17 = False,
    allow_late_surrender = False,
    allow_early_surrender_on_ten = False,
    allow_early_surrender_on_ace = False,
    allow_early_surrender_on_all = False,
    dealer_shows_card_on_surrender = True,
    allow_insurance_vs_ace = True,
    natural_blackjack_payout = 3 / 2,
    surrender_payout = 1 / 2,
    insurance_payout = 2 / 1,
    max_splits_allowed = 1,
    allow_action_on_split_aces = True,
    allow_double_after_split = True,
    allow_double_on_soft = True,
    allow_split_different_tens = True,
    no_natural_bj_on_split = True,
    split_order_reversed = True
)

# %%
def card_list_str_to_rank_values(card_list_str):
    return tuple(Rank(s[:-1]).rank_value() for s in card_list_str)


class Player:
    def __init__(self, actor, scr_taker, card_counter, strategy):
        self.actor = actor
        self.scr_taker = scr_taker  # "/media/maxim/T7/frames/")
        self.round = BJRound(rules)
        self.active_hand_position = get_cards_tablet.HandPosition.NONE
        self.card_counter = card_counter
        self.strategy = strategy

    def is_pre_shuffle(self):
        game_img = self.scr_taker.get_screen()
        return get_cards_tablet.is_pre_shuffle(game_img)

    def reset_hands(self):
        self.round = BJRound(rules)
        self.active_hand_position = get_cards_tablet.HandPosition.NONE

    def play_round(self, bet=1000):
        self.reset_hands()
        self.initial_stage_round(bet)
        # check if round is over after initial stage - dealer or player has blackjack
        if self.round.get_stage() != BJStage.ROUND_OVER:
            self.decisions_stage_round()
        self.end_round()


    def initial_stage_round(self, bet):
        game_img = self.scr_taker.get_screen()
        while not get_cards_tablet.is_table_empty(game_img):
            time.sleep(0.5)
            game_img = self.scr_taker.get_screen()
        self.round.start_round(bet)
        self.actor.place_bet(bet)
        self.actor.deal()
        self.wait_for_initial_cards()

        print("initial hand")
        print(self.round)
        print("true count: ", self.card_counter.get_true_count())

        player_had_bj = self.round.player_hands[0].is_natural_blackjack()

        if not player_had_bj:
            if self.round.get_dealer_hand()[0] == 10:
                self.wait_for_dealer_bj_or_action_request()
            elif self.round.get_dealer_hand()[0] == 11:
                # if dealer has A, insurance is always offered
                self.refuse_insurance()
                self.wait_for_dealer_bj_or_action_request()
            else:
                self.wait_for_action_request()
        else:  # player has blackjack
            if self.round.get_dealer_hand()[0] == 11:
                self.refuse_insurance()
            # sometimes dealer both 2 cards are captured by wait_for_initial_cards
            # instead of one
            self.wait_for_dealer_full_hand(only_two_cards=True)



    def decisions_stage_round(self):
        while self.round.need_player_action():
            player_hand = self.round.get_active_player_hand()
            dealer_hand = self.round.get_dealer_hand()
                
            strategy_actions = self.strategy.get_actions(
                player_hand.get_best_value(),
                player_hand.is_soft(),
                player_hand.is_same_value_pair(),
                dealer_hand.get_best_value(),
                self.card_counter.get_true_count()
            )
            possible_actions = self.round.get_available_actions()
            for action in strategy_actions:
                if action in possible_actions:
                    self.take_action(action)
                    break
        
        self.wait_for_dealer_full_hand(
            only_two_cards=all(hand.is_bust() for hand in self.round.player_hands)
        )


    def take_action(self, action):
        if action == PlayerAction.DOUBLE:
            self.double()
        elif action == PlayerAction.SPLIT:
            self.split()
        elif action == PlayerAction.HIT:
            self.hit()
        elif action == PlayerAction.STAND:
            self.stand()
        elif action == PlayerAction.REFUSE_INSURANCE:
            self.refuse_insurance()
        elif action == PlayerAction.TAKE_INSURANCE:
            self.take_insurance()
        else:
            raise ValueError(f"Unsupported action {action}")

    def double(self):
        self.wait_for_action_btn()
        self.btn_action_delay()
        self.actor.double()
        self.round.take_action(PlayerAction.DOUBLE)
        self.wait_for_player_card()

    def split(self):
        self.wait_for_action_btn()
        self.btn_action_delay()
        self.actor.split()
        self.round.take_action(PlayerAction.SPLIT)
        self.wait_for_player_card()
        self.wait_for_player_card()

    def hit(self):
        self.wait_for_action_btn()
        self.btn_action_delay()
        self.actor.hit()
        self.round.take_action(PlayerAction.HIT)
        self.wait_for_player_card()

    def stand(self):
        self.wait_for_action_btn()
        self.btn_action_delay()
        self.actor.stand()
        self.round.take_action(PlayerAction.STAND)

    def refuse_insurance(self):
        self.wait_for_insurance_option()
        self.actor.refuse_insurance()
        self.round.take_action(PlayerAction.REFUSE_INSURANCE)

    def take_insurance(self):
        self.wait_for_insurance_option()
        self.actor.take_insurance()
        self.round.take_action(PlayerAction.TAKE_INSURANCE)

    def btn_action_delay(self):
        # active_hand = self.round.get_active_player_hand()
        # hand_idx = self.round.active_hand_idx
        # # if the hand is the second hand in a pair, 
        # # and this is a first action, add a delay
        # if hand_idx > 0 and len(active_hand) == 2:     
        time.sleep(1)

    def take_card(self, card):
        self.round.take_card(card)
        self.card_counter.update_count(card)

    def wait_for_action_btn(self):
        while True:
            game_img = self.scr_taker.get_screen()
            can_stand = get_cards_tablet.can_hit_stand(game_img)
            if can_stand:
                break

    def end_round(self):
        print("final stage")
        assert self.round.get_stage() == BJStage.ROUND_OVER
        print(self.round)

        self.actor.rebuy()
        

    def wait_for_initial_cards(self):
        print("wait_for_initial_cards")
        game_img = self.scr_taker.get_screen()
        dealer_cards_new = card_list_str_to_rank_values(get_cards_tablet.get_dealer_cards(game_img))
        middle_cards_new = card_list_str_to_rank_values(get_cards_tablet.get_player_cards_middle(game_img))

        dealer_cards_last = dealer_cards_new
        middle_cards_last = middle_cards_new

        cards_confirmed = False
        while True:
            if (
                cards_confirmed 
                and len(dealer_cards_new) >= 1
                and len(middle_cards_new) >= 2
            ):
                break

            game_img = self.scr_taker.get_screen()
            dealer_cards_new = card_list_str_to_rank_values(get_cards_tablet.get_dealer_cards(game_img))
            middle_cards_new = card_list_str_to_rank_values(get_cards_tablet.get_player_cards_middle(game_img))

            if dealer_cards_new == dealer_cards_last and middle_cards_new == middle_cards_last:
                cards_confirmed = True
            else:
                cards_confirmed = False
                dealer_cards_last = dealer_cards_new
                middle_cards_last = middle_cards_new

        self.take_card(middle_cards_new[0])
        self.take_card(middle_cards_new[1])
        self.take_card(dealer_cards_new[0])
        # on this stage the dealer can show 2 cards - if she has blackjack 
        # or if player has bj and she shows that she doesn't have one
        if len(dealer_cards_new) >= 2:
            if sum(dealer_cards_new) == 21:
                self.round.take_action(DealerAction.CONFIRM_BLACKJACK)
            else:
                self.round.take_action(DealerAction.CONFIRM_NO_BLACKJACK)
            self.take_card(dealer_cards_new[1])


    def wait_for_insurance_option(self):
        print("wait_for_insurance_option")
        game_img = self.scr_taker.get_screen()
        while not get_cards_tablet.is_insurance_offered(game_img):
            game_img = self.scr_taker.get_screen()


    def wait_for_action_request(self):
        print("wait_for_action_request")
        while True:
            if self.active_hand_position != get_cards_tablet.HandPosition.NONE:
                break
            game_img = self.scr_taker.get_screen()
            self.active_hand_position = get_cards_tablet.get_active_hand(game_img)


    def wait_for_dealer_bj_or_action_request(self):
        # after insurance refused dealer either shows bj or points to my hand
        print("wait_for_dealer_bj_or_action_request")
        current_dealer_hand = self.round.get_dealer_hand()
        if len(current_dealer_hand) >= 2:
            # dealer already has 2 cards - this is only possible if dealer has blackjack
            # and this was confirmed when checking initial cards
            return
        
        game_img = self.scr_taker.get_screen()
        dealer_cards_new = card_list_str_to_rank_values(get_cards_tablet.get_dealer_cards(game_img))
        dealer_cards_last = dealer_cards_new
        
        dealer_cards_confirmed = False
        action_request = False
        dealer_blackjack = False
        while True:
            # dealer shows blackjack
            if dealer_cards_confirmed and len(dealer_cards_new) >= 2:
                dealer_blackjack = True
                break
            # dealer asks for action
            if self.active_hand_position != get_cards_tablet.HandPosition.NONE:
                action_request = True
                break
                
            game_img = self.scr_taker.get_screen()
            self.active_hand_position = get_cards_tablet.get_active_hand(game_img)
            dealer_cards_new = card_list_str_to_rank_values(get_cards_tablet.get_dealer_cards(game_img))
            
            if dealer_cards_new == dealer_cards_last:
                dealer_cards_confirmed = True
            else:
                dealer_cards_last = dealer_cards_new
                dealer_cards_confirmed = False

        if dealer_blackjack:
            self.round.take_action(DealerAction.CONFIRM_BLACKJACK)
            self.take_card(dealer_cards_new[1])
        else:
            self.round.take_action(DealerAction.CONFIRM_NO_BLACKJACK)
        

    def wait_for_dealer_full_hand(self, only_two_cards=False):
        print("wait_for_dealer_full_hand")
        if only_two_cards and len(self.round.get_dealer_hand()) >= 2:
            return
        
        game_img = self.scr_taker.get_screen()

        dealer_cards_new = card_list_str_to_rank_values(get_cards_tablet.get_dealer_cards(game_img))
        dealer_cards_last = dealer_cards_new
        current_hand = ValueOnlyHand(dealer_cards_new)
        
        dealer_confirmed = False
        
        n_start_cards = len(self.round.get_dealer_hand())
        while True:
            if dealer_confirmed: 
                if only_two_cards:
                    if len(current_hand) >= 2:
                        break
                else:
                    if current_hand.is_bust() or current_hand.get_best_value() >= 17:
                        break
        
            game_img = self.scr_taker.get_screen()
            dealer_cards_new = card_list_str_to_rank_values(get_cards_tablet.get_dealer_cards(game_img))
            # print(dealer_cards_new)
            if dealer_cards_new == dealer_cards_last:
                dealer_confirmed = True
                current_hand = ValueOnlyHand(dealer_cards_new)
            else:
                dealer_confirmed = False
                dealer_cards_last = dealer_cards_new
                current_hand = None

        if self.round.get_stage() == BJStage.DEALER_CHECK_BJ:
            print("second check bj tested")
            if sum(dealer_cards_new) == 21:
                self.round.take_action(DealerAction.CONFIRM_BLACKJACK)
            else:
                self.round.take_action(DealerAction.CONFIRM_NO_BLACKJACK)

        for c in current_hand.cards[n_start_cards:]:
            self.take_card(c)


    def wait_for_player_card(self):
        print("wait_for_player_card")
        round_hand_idx = self.round.active_hand_idx
        n_hands = len(self.round.player_hands)
        if n_hands == 1 and round_hand_idx == 0:
            self.active_hand_position = get_cards_tablet.HandPosition.MIDDLE
        elif n_hands == 2 and round_hand_idx == 0:
            # hands go in the order of right -> left
            self.active_hand_position = get_cards_tablet.HandPosition.RIGHT
        elif n_hands == 2 and round_hand_idx == 1:
            self.active_hand_position = get_cards_tablet.HandPosition.LEFT
        else:
            raise ValueError(f"Unsupported hands state n={n_hands}, idx={round_hand_idx}")
        
        hand = self.round.get_active_player_hand()
        
        # 4 cards in each line 
        n_cards_last_line = len(hand) % 4
        if len(hand) > 0 and n_cards_last_line == 0:
            n_cards_last_line = 4

        # print(n_cards_last_line)
        # 6th card covers cards 1,2,3,4 (entire previous line)
        visible_tail_idx = slice(-n_cards_last_line, None)
        if n_cards_last_line == 4:
            # 5th card covers cards 1,2,3
            visible_tail_idx = slice(-1, None)
        # 6th (2nd in the new line) will cover the entire previous line
        # no need to adjust slice, just take the last (current) line
        
        visible_old_tail = tuple(hand[visible_tail_idx])
        game_img = self.scr_taker.get_screen()
        hand_cards_new = card_list_str_to_rank_values(
            get_cards_tablet.get_player_cards(game_img, self.active_hand_position)
        )
        hand_cards_last = hand_cards_new
        
        hand_confirmed = False
        while True:
            # print(hand_confirmed, hand_cards_new, visible_old_tail)
            if (
                hand_confirmed 
                and hand_cards_new[:-1] == visible_old_tail
                and len(hand_cards_new) == len(visible_old_tail) + 1
            ):
                break

            game_img = self.scr_taker.get_screen()
            hand_cards_new = card_list_str_to_rank_values(
                get_cards_tablet.get_player_cards(game_img, self.active_hand_position)
            )
            
            if hand_cards_new == hand_cards_last:
                hand_confirmed = True
            else:
                hand_confirmed = False
                hand_cards_last = hand_cards_new
        
        new_card = hand_cards_new[-1]
        self.take_card(new_card)

# %%
def bet_size_ramp(tc_int):
    if tc_int >= 6:
        return 20
    elif tc_int >= 5:
        return 18
    elif tc_int >= 4:
        return 14
    elif tc_int >= 3:
        return 10
    elif tc_int >= 2:
        return 6
    elif tc_int >= 1:
        return 3
    else:
        return 1

# %%
def close_ads(actor, src_taker):
    ignore_region_xy = [[1700,1780], [1350, 1430]]
    def not_in_ignore_region(xy_position):
        return not (
            ignore_region_xy[0][0] < xy_position[0] < ignore_region_xy[0][1]
            and ignore_region_xy[1][0] < xy_position[1] < ignore_region_xy[1][1]
        )

    game_img = src_taker.get_screen()
    ads_crosses = get_cards_tablet.find_close_ad_crosses(game_img)
    ads_crosses = list(filter(not_in_ignore_region, ads_crosses))

    while len(ads_crosses) > 0:
        for xy_position in ads_crosses:
            print(xy_position)
            actor.click(*xy_position)
        time.sleep(1)
        game_img = src_taker.get_screen()
        ads_crosses = get_cards_tablet.find_close_ad_crosses(game_img)
        ads_crosses = list(filter(not_in_ignore_region, ads_crosses))


def restart_table(actor, src_taker):
    # leave table
    actor.leave_table()

    # wait
    game_img = src_taker.get_screen()
    while not get_cards_tablet.can_create_private_table(game_img):
        time.sleep(1)
        game_img = src_taker.get_screen()

    close_ads(actor, src_taker)

    while get_cards_tablet.can_create_private_table(game_img):
        actor.create_private_table()
        time.sleep(1)
        game_img = src_taker.get_screen()

# %%
play_log_filename = "logs/play.csv"

# columns
# dealer_hand, player_hand_0, player_hand_1, total_bet, net_value, datetime up to second

def create_header_if_not_exists():
    if not os.path.exists(play_log_filename):
        with open(play_log_filename, 'w') as f:
            f.write("shoe_hand_idx,dealer_hand,player_hand_0,player_hand_1,total_bet,net_value,true_count,remaining_cards,datetime\n")

create_header_if_not_exists()

def card_to_str_line(hand):
    return " ".join(str(rank) for rank in hand.cards)

def log_play_stats(shoe_hand_idx, round, counter):
    dealer_hand_str = str(round.get_dealer_hand())
    player_hand_0_str = card_to_str_line(round.player_hands[0])
    if len(round.player_hands) > 1:
        player_hand_1_str = card_to_str_line(round.player_hands[1])
    else:
        player_hand_1_str = ""
    total_bet = round.get_player_bet()
    net_value = round.get_player_value()

    now = datetime.now()
    dt_string = now.strftime("%Y-%m-%d %H:%M:%S")

    with open(play_log_filename, 'a') as f:
        line = ",".join([
            str(shoe_hand_idx),
            dealer_hand_str,
            player_hand_0_str,
            player_hand_1_str,
            total_bet,
            net_value,
            counter.true_count,
            counter.remaining_cards,
            dt_string
        ])
        f.write(line)
        f.write("\n")

# %%
src_taker = None
del src_taker

all_cards = []
net_value = []

src_taker = ScreenCapture()
game_img = src_taker.get_screen()
initial_penetration = 0 # get_cards_tablet.get_shoe_penetration(game_img)
print("initial_penetration", initial_penetration)
counter = CardCounter(n_decks=6, current_penetration=initial_penetration)
actor = AndroidBJTabletActor([250, 500, 1000, 2500, 5000])
# Out:
# initial_penetration 0

# %%
restart_table(actor, src_taker)
# Out:
# (np.int64(1707), np.int64(1032))
# (np.int64(1893), np.int64(1179))
# (np.int64(2045), np.int64(1177))

# %%
strategy = DeviatedBasicStrategy("strategy", "strategy")

# %%
p = Player(actor, src_taker, counter, strategy)
game_img = src_taker.get_screen()
shoe_hand_idx = 0

while not get_cards_tablet.is_pre_shuffle(game_img):
    print(f"start, tc = {counter.get_true_count()}")
    int_tc = counter.get_integer_tc()
    bet = bet_size_ramp(int_tc) * 250

    p.play_round(bet)

    for hand in p.round.player_hands:
        all_cards.extend(hand.cards)
    all_cards.extend(p.round.dealer_hand.cards)
    net_value.append(p.round.get_player_value())
    
    log_play_stats(shoe_hand_idx, p.round, counter)
    
    shoe_hand_idx += 1
    
    if shoe_hand_idx >= 2 and counter.get_true_count() < 0:
        restart_table(actor, src_taker)
        counter.reset()
        shoe_hand_idx = 0

    game_img = src_taker.get_screen()
    time.sleep(1)
# Out:
# start, tc = 0.0
# wait_for_initial_cards
# initial hand
# Last card: 9
# Dealer 9,X
# Player 6,6(12)[$250]
# true count:  0.3365695792880259
# wait_for_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 6
# Dealer 9,6(15)
# Player 6,6,10(22/bust)[$250]
# Player total bet: 250
# Player total payout: 0
# Player net: -250
# start, tc = 0.33876221498371334
# wait_for_initial_cards
# initial hand
# Last card: 3
# Dealer 3,X
# Player 3,A(4/14)[$250]
# true count:  0.5131578947368421
# wait_for_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 9
# Dealer 3,5,9(17)
# Player 3,A,4(8/18)-stand[$250]
# Player total bet: 250
# Player total payout: 500
# Player net: +250
# start, tc = 0.8637873754152824
# wait_for_initial_cards
# initial hand
# Last card: 5
# Dealer 5,X
# Player 10,8(18)[$250]
# true count:  0.87248322147651
# wait_for_action_request
# wait_for_dealer_full_hand
# final stage
# Last card: 2
# Dealer 5,5,5,2(17)
# Player 10,8(18)-stand[$250]
# Player total bet: 250
# Player total payout: 500
# Player net: +250
# start, tc = 1.4101694915254237
# wait_for_initial_cards
# initial hand
# Last card: 11
# Dealer 11,X
# Player 10,10(20)[$750]
# true count:  0.8904109589041097
# wait_for_insurance_option
# wait_for_dealer_bj_or_action_request
# final stage
# Last card: 10
# Dealer A,10(11/21)
# Player 10,10(20)[$750]
# Player total bet: 750
# Player total payout: 0
# Player net: -750
# start, tc = 0.7147766323024055
# wait_for_initial_cards
# initial hand
# Last card: 6
# Dealer 6,X
# Player A,10(11/21) bj[$250]
# true count:  0.5416666666666666
# wait_for_dealer_full_hand
# final stage
# Last card: 6
# Dealer 6,6(12)
# Player A,10(11/21) bj[$250]
# Player total bet: 250
# Player total payout: 625.0
# Player net: +375.0
# start, tc = 0.7247386759581882
# wait_for_initial_cards
# initial hand
# Last card: 4
# Dealer 4,X
# Player 6,10(16)[$250]
# true count:  0.9154929577464789
# wait_for_action_request
# wait_for_dealer_full_hand
# final stage
# Last card: 6
# Dealer 4,2,10,6(22/bust)
# Player 6,10(16)-stand[$250]
# Player total bet: 250
# Player total payout: 500
# Player net: +250
# start, tc = 1.1103202846975089
# wait_for_initial_cards
# initial hand
# Last card: 10
# Dealer 10,X
# Player 3,4(7)[$750]
# true count:  1.3093525179856116
# wait_for_dealer_bj_or_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 10
# Dealer 10,6,10(26/bust)
# Player 3,4,10(17)-stand[$750]
# Player total bet: 750
# Player total payout: 1500
# Player net: +750
# start, tc = 1.1345454545454545
# wait_for_initial_cards
# initial hand
# Last card: 10
# Dealer 10,X
# Player 4,10(14)[$750]
# true count:  0.9558823529411764
# wait_for_dealer_bj_or_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 6
# Dealer 10,6(16)
# Player 4,10,10(24/bust)[$750]
# Player total bet: 750
# Player total payout: 0
# Player net: -750
# start, tc = 0.9629629629629629
# wait_for_initial_cards
# initial hand
# Last card: 8
# Dealer 8,X
# Player 10,A(11/21) bj[$250]
# true count:  0.5842696629213483
# wait_for_dealer_full_hand
# final stage
# Last card: 4
# Dealer 8,4(12)
# Player 10,A(11/21) bj[$250]
# Player total bet: 250
# Player total payout: 625.0
# Player net: +375.0
# start, tc = 0.7819548872180452
# wait_for_initial_cards
# initial hand
# Last card: 11
# Dealer 11,X
# Player 10,10(20)[$250]
# true count:  0.19771863117870722
# wait_for_insurance_option
# wait_for_dealer_bj_or_action_request
# wait_for_dealer_full_hand
# final stage
# Last card: 5
# Dealer A,2,5(8/18)
# Player 10,10(20)-stand[$250]
# Player total bet: 250
# Player total payout: 500
# Player net: +250
# start, tc = 0.5977011494252874
# wait_for_initial_cards
# initial hand
# Last card: 10
# Dealer 10,X
# Player 3,4(7)[$250]
# true count:  0.8062015503875969
# wait_for_dealer_bj_or_action_request
# wait_for_player_card
# wait_for_player_card
# wait_for_player_card
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 10
# Dealer 10,10(20)
# Player 3,4,5,3,A,10(26/bust)[$250]
# Player total bet: 250
# Player total payout: 0
# Player net: -250
# start, tc = 0.6166007905138341
# wait_for_initial_cards
# initial hand
# Last card: 2
# Dealer 2,X
# Player 9,9(18)[$250]
# true count:  0.8320000000000001
# wait_for_action_request
# wait_for_player_card
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 6
# Dealer 2,3,A,10,6(22/bust)
# Player 9,8(17)-stand[$250] | 9,10(19)-stand[$250]
# Player total bet: 500
# Player total payout: 1000
# Player net: +500
# start, tc = 0.6393442622950819
# wait_for_initial_cards
# initial hand
# Last card: 4
# Dealer 4,X
# Player 6,10(16)[$250]
# true count:  0.8630705394190871
# wait_for_action_request
# wait_for_dealer_full_hand
# final stage
# Last card: 4
# Dealer 4,A,A,4(10/20)
# Player 6,10(16)-stand[$250]
# Player total bet: 250
# Player total payout: 0
# Player net: -250
# start, tc = 0.6554621848739496
# wait_for_initial_cards
# initial hand
# Last card: 8
# Dealer 8,X
# Player 10,5(15)[$250]
# true count:  0.6638297872340425
# wait_for_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 8
# Dealer 8,8(16)
# Player 10,5,8(23/bust)[$250]
# Player total bet: 250
# Player total payout: 0
# Player net: -250
# start, tc = 0.6695278969957081
# wait_for_initial_cards
# initial hand
# Last card: 5
# Dealer 5,X
# Player 10,10(20)[$250]
# true count:  0.45217391304347826
# wait_for_action_request
# wait_for_dealer_full_hand
# final stage
# Last card: 5
# Dealer 5,10,5(20)
# Player 10,10(20)-stand[$250]
# Player total bet: 250
# Player total payout: 250
# Player net: 0
# start, tc = 0.45614035087719296
# wait_for_initial_cards
# initial hand
# Last card: 9
# Dealer 9,X
# Player 8,9(17)[$250]
# true count:  0.46222222222222226
# wait_for_action_request
# wait_for_dealer_full_hand
# final stage
# Last card: 10
# Dealer 9,4,10(23/bust)
# Player 8,9(17)-stand[$250]
# Player total bet: 250
# Player total payout: 500
# Player net: +250
# start, tc = 0.4663677130044843
# wait_for_initial_cards
# initial hand
# Last card: 10
# Dealer 10,X
# Player 8,2(10)[$250]
# true count:  0.4727272727272727
# wait_for_dealer_bj_or_action_request
# wait_for_player_card
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 9
# Dealer 10,3,9(22/bust)
# Player 8,2,4,7(21)-stand[$250]
# Player total bet: 250
# Player total payout: 500
# Player net: +250
# start, tc = 0.9629629629629629
# wait_for_initial_cards
# initial hand
# Last card: 9
# Dealer 9,X
# Player 7,8(15)[$250]
# true count:  0.9765258215962442
# wait_for_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 6
# Dealer 9,6(15)
# Player 7,8,8(23/bust)[$250]
# Player total bet: 250
# Player total payout: 0
# Player net: -250
# start, tc = 1.2322274881516588
# wait_for_initial_cards
# initial hand
# Last card: 3
# Dealer 3,X
# Player 10,10(20)[$750]
# true count:  1.0
# wait_for_action_request
# wait_for_dealer_full_hand
# final stage
# Last card: 9
# Dealer 3,3,8,9(23/bust)
# Player 10,10(20)-stand[$750]
# Player total bet: 750
# Player total payout: 1500
# Player net: +750
# start, tc = 1.2682926829268293
# wait_for_initial_cards
# initial hand
# Last card: 7
# Dealer 7,X
# Player A,3(4/14)[$750]
# true count:  1.2871287128712872
# wait_for_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 10
# Dealer 7,10(17)
# Player A,3,7(11/21)-stand[$750]
# Player total bet: 750
# Player total payout: 1500
# Player net: +750
# start, tc = 1.04
# wait_for_initial_cards
# initial hand
# Last card: 10
# Dealer 10,X
# Player 2,7(9)[$750]
# true count:  1.0558375634517767
# wait_for_dealer_bj_or_action_request
# wait_for_player_card
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 10
# Dealer 10,10(20)
# Player 2,7,7,7(23/bust)[$750]
# Player total bet: 750
# Player total payout: 0
# Player net: -750
# start, tc = 0.8041237113402062
# wait_for_initial_cards
# initial hand
# Last card: 6
# Dealer 6,X
# Player 10,6(16)[$250]
# true count:  1.0890052356020943
# wait_for_action_request
# wait_for_dealer_full_hand
# final stage
# Last card: 4
# Dealer 6,10,4(20)
# Player 10,6(16)-stand[$250]
# Player total bet: 250
# Player total payout: 0
# Player net: -250
# start, tc = 1.1005291005291005
# wait_for_initial_cards
# initial hand
# Last card: 5
# Dealer 5,X
# Player 5,3(8)[$750]
# true count:  1.9569892473118278
# wait_for_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 7
# Dealer 5,6,7(18)
# Player 5,3,10(18)-stand[$750]
# Player total bet: 750
# Player total payout: 750
# Player net: 0
# start, tc = 1.989071038251366
# wait_for_initial_cards
# initial hand
# Last card: 5
# Dealer 5,X
# Player 10,10(20)[$750]
# true count:  1.7333333333333332
# wait_for_action_request
# wait_for_dealer_full_hand
# final stage
# Last card: 3
# Dealer 5,10,3(18)
# Player 10,10(20)-stand[$750]
# Player total bet: 750
# Player total payout: 1500
# Player net: +750
# start, tc = 1.752808988764045
# wait_for_initial_cards
# initial hand
# Last card: 11
# Dealer 11,X
# Player 8,5(13)[$750]
# true count:  1.782857142857143
# wait_for_insurance_option
# wait_for_dealer_bj_or_action_request
# wait_for_player_card
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 11
# Dealer A,A(2/12)
# Player 8,5,2,9(24/bust)[$750]
# Player total bet: 750
# Player total payout: 0
# Player net: -750
# start, tc = 1.8139534883720931
# wait_for_initial_cards
# initial hand
# Last card: 10
# Dealer 10,X
# Player 10,3(13)[$750]
# true count:  1.5384615384615385
# wait_for_dealer_bj_or_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 8
# Dealer 10,8(18)
# Player 10,3,4(17)-stand[$750]
# Player total bet: 750
# Player total payout: 0
# Player net: -750
# start, tc = 1.868263473053892
# wait_for_initial_cards
# initial hand
# Last card: 2
# Dealer 2,X
# Player 10,10(20)[$750]
# true count:  1.5853658536585367
# wait_for_action_request
# wait_for_dealer_full_hand
# final stage
# Last card: 10
# Dealer 2,10,10(22/bust)
# Player 10,10(20)-stand[$750]
# Player total bet: 750
# Player total payout: 1500
# Player net: +750
# start, tc = 0.9629629629629629
# wait_for_initial_cards
# initial hand
# Last card: 8
# Dealer 8,X
# Player 8,10(18)[$250]
# true count:  0.6540880503144655
# wait_for_action_request
# wait_for_dealer_full_hand
# final stage
# Last card: 9
# Dealer 8,9(17)
# Player 8,10(18)-stand[$250]
# Player total bet: 250
# Player total payout: 500
# Player net: +250
# start, tc = 0.6582278481012659
# wait_for_initial_cards
# initial hand
# Last card: 11
# Dealer 11,X
# Player 10,2(12)[$250]
# true count:  0.3354838709677419
# wait_for_insurance_option
# wait_for_dealer_bj_or_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 9
# Dealer A,9(10/20)
# Player 10,2,9(21)-stand[$250]
# Player total bet: 250
# Player total payout: 500
# Player net: +250
# start, tc = 0.3398692810457516
# wait_for_initial_cards
# initial hand
# Last card: 4
# Dealer 4,X
# Player 2,8(10)[$250]
# true count:  1.04
# wait_for_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 10
# Dealer 4,10,10(24/bust)
# Player 2,8,2(12)-stand[$500]
# Player total bet: 500
# Player total payout: 1000
# Player net: +500
# start, tc = 0.7074829931972789
# wait_for_initial_cards
# initial hand
# Last card: 11
# Dealer 11,X
# Player 7,5(12)[$250]
# true count:  0.7222222222222222
# wait_for_insurance_option
# wait_for_dealer_bj_or_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 7
# Dealer A,7(8/18)
# Player 7,5,10(22/bust)[$250]
# Player total bet: 250
# Player total payout: 0
# Player net: -250
# start, tc = 0.36619718309859156
# wait_for_initial_cards
# initial hand
# Last card: 10
# Dealer 10,X
# Player A,5(6/16)[$250]
# true count:  0.0
# wait_for_dealer_bj_or_action_request
# wait_for_player_card
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 10
# Dealer 10,10(20)
# Player A,5,10,6(22/bust)[$250]
# Player total bet: 250
# Player total payout: 0
# Player net: -250
# (np.int64(1707), np.int64(1032))
# (np.int64(1758), np.int64(1097))
# (np.int64(2247), np.int64(1271))
# start, tc = -0.38235294117647056
# wait_for_initial_cards
# initial hand
# Last card: 10
# Dealer 10,X
# Player 3,3(6)[$250]
# true count:  0.0
# wait_for_dealer_bj_or_action_request
# wait_for_player_card
# wait_for_player_card
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 10
# Dealer 10,10(20)
# Player 3,3,3,2,7(18)-stand[$250]
# Player total bet: 250
# Player total payout: 0
# Player net: -250
# start, tc = 0.40310077519379844
# wait_for_initial_cards
# initial hand
# Last card: 9
# Dealer 9,X
# Player 3,10(13)[$250]
# true count:  0.41269841269841273
# wait_for_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 9
# Dealer 9,9(18)
# Player 3,10,10(23/bust)[$250]
# Player total bet: 250
# Player total payout: 0
# Player net: -250
# start, tc = 0.0
# wait_for_initial_cards
# initial hand
# Last card: 6
# Dealer 6,X
# Player 10,8(18)[$250]
# true count:  0.0
# wait_for_action_request
# wait_for_dealer_full_hand
# final stage
# Last card: 4
# Dealer 6,8,4(18)
# Player 10,8(18)-stand[$250]
# Player total bet: 250
# Player total payout: 250
# Player net: 0
# start, tc = 0.4369747899159664
# wait_for_initial_cards
# initial hand
# Last card: 8
# Dealer 8,X
# Player 9,6(15)[$250]
# true count:  0.896551724137931
# wait_for_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 9
# Dealer 8,9(17)
# Player 9,6,10(25/bust)[$250]
# Player total bet: 250
# Player total payout: 0
# Player net: -250
# start, tc = 0.45614035087719296
# wait_for_initial_cards
# initial hand
# Last card: 7
# Dealer 7,X
# Player 6,10(16)[$250]
# true count:  0.46846846846846846
# wait_for_action_request
# wait_for_player_card
# wait_for_dealer_full_hand
# final stage
# Last card: 10
# Dealer 7,10(17)
# Player 6,10,10(26/bust)[$250]
# Player total bet: 250
# Player total payout: 0
# Player net: -250
# start, tc = -0.4770642201834862
# wait_for_initial_cards
# initial hand
# Last card: 5
# Dealer 5,X
# Player 10,3(13)[$250]
# true count:  0.0
# wait_for_action_request
# wait_for_dealer_full_hand
# final stage
# Last card: 7
# Dealer 5,10,7(22/bust)
# Player 10,3(13)-stand[$250]
# Player total bet: 250
# Player total payout: 500
# Player net: +250
# (np.int64(1777), np.int64(1040))
# (np.int64(1896), np.int64(1102))
# (np.int64(1758), np.int64(1097))
# start, tc = -0.5
# wait_for_initial_cards
# initial hand
# Last card: 10
# Dealer 10,X
# Player 2,4(6)[$250]
# true count:  0.0
# wait_for_dealer_bj_or_action_request
# final stage
# Last card: 11
# Dealer 10,A(11/21)
# Player 2,4(6)[$250]
# Player total bet: 250
# Player total payout: 0
# Player net: -250
# start, tc = -0.52
# wait_for_initial_cards
# initial hand
# Last card: 5
# Dealer 5,X
# Player 9,10(19)[$250]
# true count:  -0.5360824742268041
# wait_for_action_request
# wait_for_dealer_full_hand
# final stage
# Last card: 6
# Dealer 5,8,6(19)
# Player 9,10(19)-stand[$250]
# Player total bet: 250
# Player total payout: 250
# Player net: 0

# %%
print(p.round)
# Out:
# Last card: 11
# Dealer 3,A(4/14)
# Player 7,2,5(14)-stand[$2000]

# %%
p.round.get_stage()
# Out:
# <BJStage.ROUND_OVER: 8>

# %%
p.round.get_stage()
# Out:
# <BJStage.ROUND_OVER: 8>

# %%
# conclusion is that there are 6 decks
# deck penetration is 82.37179487179488
