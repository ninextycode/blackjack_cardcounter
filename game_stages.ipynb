# %%
# %matplotlib widget

import os
import numpy as np
from PIL import Image
import cv2
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import patheffects as pe
import pytesseract
import image_utils
from matplotlib.patches import Polygon
import get_cards_tablet

# %%
# Load image into a NumPy array

# img_path = "frames_tablet/dealer_4_cards.png"  # player has d
# split2 / split5 finger position
img_path = "frames_tablet/insurance_bet.png"

if not os.path.exists(img_path):
    raise FileNotFoundError(f"Image not found: {img_path}")

img_np = image_utils.load_rdb(img_path)

print(f"Loaded {img_path}")
print(f"shape: {img_np.shape}, dtype: {img_np.dtype}")

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 6))
f.tight_layout()
ax.set_aspect(1)
ax.imshow(img_np, aspect='equal')

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 6))
f.tight_layout()
ax.set_aspect(1)


insurance_block = img_np[680:731, 1185:1411]

ax.imshow(insurance_block, aspect='equal')

# %%
match = cv2.matchTemplate(
    insurance_block, insurance_block, cv2.TM_CCOEFF_NORMED
)

# %%
match.shape

# %%
img_path_0 = "frames_tablet/Th4c_8d.png"
img_path_1 = "frames_tablet/split_2.png"
img_path_2 = "frames_tablet/split_5.png"
img_path_3 = "frames_tablet/split_offer.png"

img_np_0 = image_utils.load_rdb(img_path_0)
img_np_1 = image_utils.load_rdb(img_path_1)
img_np_2 = image_utils.load_rdb(img_path_2)
img_np_3 = image_utils.load_rdb(img_path_3)

# %%
f, [ax0, ax1, ax2, ax3] = plt.subplots(4, 1, figsize=(8, 12), sharex=True, sharey=True)
f.tight_layout()
ax0.imshow(img_np_0, aspect='equal')
ax1.imshow(img_np_1, aspect='equal')
ax2.imshow(img_np_2, aspect='equal')
ax3.imshow(img_np_3, aspect='equal')

# %%
finger_area = (slice(545, 620), slice(1150, 1400))

# %%
f, [ax0, ax1, ax2, ax3] = plt.subplots(4, 1, figsize=(8, 12), sharex=True, sharey=True)
f.tight_layout()
ax0.imshow(img_np_0[finger_area], aspect='equal')
ax1.imshow(img_np_1[finger_area], aspect='equal')
ax2.imshow(img_np_2[finger_area], aspect='equal')
ax3.imshow(img_np_3[finger_area], aspect='equal')

# %%
finger_middle = img_np_0[finger_area]
finger_left = img_np_1[finger_area]
finger_right = img_np_2[finger_area]
finger_split = img_np_3[finger_area]

# %%
# image_utils.save_rgb_png(finger_middle, "ui_elements/finger_middle.png")
# image_utils.save_rgb_png(finger_left, "ui_elements/finger_left.png")
# image_utils.save_rgb_png(finger_right, "ui_elements/finger_right.png")
# image_utils.save_rgb_png(finger_split, "ui_elements/finger_middle_split.png")

# %%
img_path = "frames_tablet/tournament_ad.png"
img_np = image_utils.load_rdb(img_path)

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 6), sharex=True, sharey=True)
f.tight_layout()
ax.imshow(img_np, aspect='equal')

# %%
ad_continue_btn_area = (slice(1300,1375), slice(900,1400))

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 6), sharex=True, sharey=True)
f.tight_layout()
ax.imshow(img_np[ad_continue_btn_area], aspect='equal')

# %%
# image_utils.save_rgb_png(img_np[ad_continue_btn_area], "ui_elements/ad_continue_btn.png")

# %%
img_path = "frames_tablet/empty_table_hilo.png"
img_np = image_utils.load_rdb(img_path)

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 6))
f.tight_layout()
ax.imshow(img_np, aspect='equal')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
empty_table_area = (slice(550, 705), slice(1000, 1375))
f, ax = plt.subplots(1, 1, figsize=(8, 6))
f.tight_layout()
ax.imshow(img_np[empty_table_area], aspect='equal')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# image_utils.save_rgb_png(img_np[empty_table_area], "ui_elements/empty_table.png")

# %%
img_path = "frames_tablet/shuffle.png"
img_np = image_utils.load_rdb(img_path)

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 6))
f.tight_layout()
ax.imshow(img_np, aspect='equal')

# %%
red_card_area = (slice(260, 286), slice(985, 1021))
f, ax = plt.subplots(1, 1, figsize=(8, 6))
f.tight_layout()
ax.imshow(img_np[red_card_area], aspect='equal')

# %%
image_utils.get_red_mask(img_np[red_card_area]).mean()

# %%
image_utils.get_blue_mask(img_np[red_card_area]).mean()

# %%
img_path = "frames_tablet/dealer_table.png"
img_np_start = image_utils.load_rdb(img_path)

# %%
poly = np.array([
    [1663, 471],
    [1564, 492],
    [1590, 556],
    [1691, 533]
], dtype=np.float32)

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 6))
f.tight_layout()
ax.imshow(img_np_start, aspect='equal')

polygon = Polygon(poly, closed=True, edgecolor='black', facecolor='none', linewidth=1)
ax.add_patch(polygon)

# %%
img_path = "frames_tablet/red_card_top.png"
img_np_end = image_utils.load_rdb(img_path)

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 6))
f.tight_layout()
ax.imshow(img_np_end, aspect='equal')
polygon = Polygon(poly, closed=True, edgecolor='black', facecolor='none', linewidth=1)
ax.add_patch(polygon)

# %%
poly

# %%
wrapped_shoe_start = image_utils.wrap_perspective(img_np_start, poly, dest_w=100, dest_h=201)
wrapped_shoe_end = image_utils.wrap_perspective(img_np_end, poly, dest_w=100, dest_h=201)

f, [ax0, ax1] = plt.subplots(1, 2, figsize=(8, 6))
f.tight_layout()
ax0.imshow(wrapped_shoe_start, aspect='equal')
ax1.imshow(wrapped_shoe_end, aspect='equal')

# %%
gray_start = cv2.cvtColor(wrapped_shoe_start, cv2.COLOR_RGB2GRAY)
gray_end = cv2.cvtColor(wrapped_shoe_end, cv2.COLOR_RGB2GRAY)

hsv_start = cv2.cvtColor(wrapped_shoe_start, cv2.COLOR_RGB2HSV)
hsv_end = cv2.cvtColor(wrapped_shoe_end, cv2.COLOR_RGB2HSV)


def get_white_mask(img_rgb):
    hsv = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2HSV)
    return get_white_mask_hsv(hsv)

def get_white_mask_hsv(hsv):
    lower_white = np.array([0, 0, 200])
    upper_white = np.array([180, 30, 255])
    mask = cv2.inRange(hsv, lower_white, upper_white)
    return mask > 0


f, [ax0, ax1] = plt.subplots(1, 2, figsize=(8, 6))
f.tight_layout()

ax0.imshow(get_white_mask_hsv(hsv_start), aspect='equal')
ax1.imshow(get_white_mask_hsv(hsv_end), aspect='equal')

# %%
white_mask_0 = get_white_mask(wrapped_shoe_start[:, :20])
white_mask_1 = get_white_mask(wrapped_shoe_end[:, :20])

# %%
white_mean_0 = white_mask_0.mean(axis=1)
white_mean_1 = white_mask_1.mean(axis=1)

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 6))
ax.plot(white_mean_0, label='start')
ax.plot(white_mean_1, label='end')

# %%
def get_first_white_line_idx(white_sum, threshold=0.9):
    for idx, val in enumerate(white_sum):
        if val > threshold:
            return idx
    return None

# %%
idx_0 = get_first_white_line_idx(white_mean_0)
idx_1 = get_first_white_line_idx(white_mean_1)

# %%
idx_0, idx_1

# %%
print(1 - ((200 - idx_0) / 200))
print(1 - ((200 - idx_1) / 200))

# %%
f, [ax0, ax1] = plt.subplots(1, 2, figsize=(8, 6))
f.tight_layout()
ax0.imshow(, aspect='equal')
ax1.imshow(, aspect='equal')

# %%
img_path = "frames_tablet/2d4h_7h.png"
img_np = image_utils.load_rdb(img_path)

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 6))
f.tight_layout()
ax.imshow(img_np, aspect='equal')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
, aspect='equal', vmin=0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
img_path = "frames_tablet/final_hand.png"
img_np = image_utils.load_rdb(img_path)

# %%
get_cards_tablet.get_shoe_penetration(img_np)
# Out:
# 0.8

# %%
img_path = "frames_tablet/menu_no_ad.png"
img_np = image_utils.load_rdb(img_path)

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 6))
f.tight_layout()
ax.imshow(img_np, aspect='equal')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
private_table_area = (slice(325, 460), slice(250, 490))
private_table = img_np[private_table_area]
f, ax = plt.subplots(1, 1, figsize=(8, 6))
f.tight_layout()
ax.imshow(private_table, aspect='equal')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
img_path = "frames_tablet/menu_with_ad.png"
img_np = image_utils.load_rdb(img_path)
private_table_grey = img_np[private_table_area]
f, ax = plt.subplots(1, 1, figsize=(8, 6))
f.tight_layout()
ax.imshow(private_table_grey, aspect='equal')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# image_utils.save_rgb_png(private_table, "ui_elements/private_table.png")
# image_utils.save_rgb_png(private_table_grey, "ui_elements/private_table_grey.png")

# %%
image_utils.get_best_match(img_np, private_table)
# Out:
# np.float32(0.99782825)

# %%
hsv = cv2.cvtColor(private_table_grey, cv2.COLOR_RGB2HSV)
print(hsv[..., 2].mean())
# Out:
# 41.625586419753084

# %%
130 / 40
